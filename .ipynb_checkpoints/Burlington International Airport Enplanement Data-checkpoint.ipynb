# %%
# %matplotlib inline
# Handle table-like data and matrices
import numpy as np
import pandas as pd
import re

# Modelling Algorithms
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression, LassoLarsCV,Ridge
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier , GradientBoostingClassifier, RandomForestRegressor

# Modelling Helpers
from sklearn.preprocessing import Imputer , Normalizer , scale
from sklearn.cross_validation import train_test_split , StratifiedKFold
from sklearn.model_selection import KFold
from sklearn.feature_selection import RFECV
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# Visualisation
import matplotlib 
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# Configure visualisations
sns.set(style="ticks")
# Out:
# C:\Users\kefor\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
wholedf = pd.read_csv('~/Desktop/PythonLearning/Burlington_International_Airport_Enplanement_Data.csv')
wholedf.head()
# Out:
#    Year  January   February  March  April    May   June   July  August  \
# 0  1988     37269     41426  42940  38565  35307  35745  40125   46080
# 1  1989     34687     37618  39216  36316  32915  37408  39329   44700
# 2  1990     33301     34714  35363  33334  31658  34545  37807   43648
# 3  1991     31675     31024  29932  32373  29597  33409  37898   41023
# 4  1992     29725     33492  33075  29249  30166  37560  43584   48460
#
#    September  October  November  December  Totals
# 0      36534    42711     34885     35963   467550
# 1      34618    42529     33603     34845   447784
# 2      35750    40898     31887     32845   425750
# 3      34062    40657     29431     34265   405346
# 4      38160    39048     30087     31557   424163

# %%
wholedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 14 columns):
# Year         26 non-null int64
# January      26 non-null int64
# February     26 non-null int64
# March        26 non-null int64
# April        26 non-null int64
# May          26 non-null int64
# June         26 non-null int64
# July         26 non-null int64
# August       26 non-null int64
# September    26 non-null int64
# October      26 non-null int64
# November     26 non-null int64
# December     26 non-null int64
# Totals       26 non-null int64
# dtypes: int64(14)
# memory usage: 2.9 KB

# %%
#Move the year into the index instead of as its own column
wholedf = wholedf.set_index('Year')

#Delete the totals column for easier plotting
del wholedf['Totals ']

# %% [markdown]
# Departure Distribution
# -----------------------
# The dataset has departure information by month since 1988 by month, but what does the distribution look like across the month for that entire time?  Do some months categorically have more, like around the holidays?

# %%
sns.kdeplot(wholedf['January ']);
sns.kdeplot(wholedf['February']);
sns.kdeplot(wholedf['March']);
sns.kdeplot(wholedf['April']);
sns.kdeplot(wholedf['May']);
sns.kdeplot(wholedf['June']);
sns.kdeplot(wholedf['July']);
sns.kdeplot(wholedf['August']);
sns.kdeplot(wholedf['September']);
sns.kdeplot(wholedf['October']);
sns.kdeplot(wholedf['November']);
sns.kdeplot(wholedf['December']);
plt.title("Distribution of Departures by Month")
plt.xlim(0,100000)
plt.show()
# Out:
# C:\Users\kefor\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# Seasonal Distribution
# --------------
# Interestingly there is no distinct jump for oliday months and the distribution has a disctint two hump distribution.  Beaking it into sets of three and all set to the sameaxis limits you can see that November and December don't have a jump but July, August and October do.

# %%
sns.kdeplot(wholedf['January ']);
sns.kdeplot(wholedf['February']);
sns.kdeplot(wholedf['March']);
sns.kdeplot(wholedf['April']);
plt.title("Distribution of Departures by Month")
plt.xlim(0,100000)
plt.show()

sns.kdeplot(wholedf['May']);
sns.kdeplot(wholedf['June']);
sns.kdeplot(wholedf['July']);
sns.kdeplot(wholedf['August']);
plt.title("Distribution of Departures by Month")
plt.xlim(0,100000)
plt.show()

sns.kdeplot(wholedf['September']);
sns.kdeplot(wholedf['October']);
sns.kdeplot(wholedf['November']);
sns.kdeplot(wholedf['December']);
plt.title("Distribution of Departures by Month")
plt.xlim(0,100000)
plt.show()
# Out:
# C:\Users\kefor\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# Monthly Values over the Years
# ---------------
# If we compare the actual plot of each month's value again you can see that July, August and October have consistantly being higher since the beginning.  Stacking the values in the bar chart allows you to see the same values in a different way.  The distribution seems to be fairly consistant over the years.

# %%
plt.figure(); wholedf.plot();
plt.title("Value of Departures by Month")
plt.show()

# %%
wholedf.plot.bar(stacked=True);
plt.title("Stacked Values of Departures by Year")
plt.show()

# %%
yearsum = wholedf.sum(axis=1)

plt.plot(yearsum)
plt.title("Total Count of Departures by Year")
plt.ylim(0,800000)
plt.show()

# %% [markdown]
# This is all odd behavior as tourims had remained at a relative flat rate.
# http://www.uvm.edu/tourismresearch/?Page=tourism.html
# http://www.uvm.edu/tourismresearch/publications/vermont-tourism-benchmark-study-2013.pdf

# %%
wholedesc = wholedf.describe()
wholedesc.describe()
# Out:
#            January       February        March         April           May  \
# count      8.000000      8.000000      8.00000      8.000000      8.000000
# mean   31573.390698  32860.772055  34679.42469  33779.504363  32504.104076
# std    18949.908101  19569.155657  20833.08917  20336.690559  19569.652382
# min       26.000000     26.000000     26.00000     26.000000     26.000000
# 25%    24429.045818  25104.318148  25006.66188  24447.475073  24653.712959
# 50%    34255.875000  37999.875000  39431.25000  37729.500000  35250.125000
# 75%    42165.894231  43649.365385  46239.06250  45406.225962  43446.298077
# max    56751.000000  57216.000000  61992.00000  60728.000000  58166.000000
#
#                June          July        August     September       October  \
# count      8.000000      8.000000      8.000000      8.000000      8.000000
# mean   35799.034064  40666.509768  43003.709090  34409.595380  40140.414011
# std    21726.829843  25140.438393  26078.942866  21070.027604  23867.652436
# min       26.000000     26.000000     26.000000     26.000000     26.000000
# 25%    27632.721975  30122.288767  33124.932602  25606.041722  31855.606868
# 50%    38733.875000  43215.125000  47568.750000  37070.250000  44592.750000
# 75%    47286.100962  53009.629808  56373.956731  46078.197115  53692.038462
# max    65845.000000  79154.000000  79304.000000  63544.000000  69556.000000
#
#            November      December
# count      8.000000      8.000000
# mean   31655.475098  32622.132465
# std    18953.043281  19526.312651
# min       26.000000     26.000000
# 25%    23756.810773  25237.139929
# 50%    34968.375000  35945.625000
# 75%    42842.605769  43855.562500
# max    55228.000000  57375.000000
