# %% [markdown]
# Pandas
# ==========
# Pandas is a powerful tool to manipulate dataframes in Python.  There are many features and examples are listed below.
#
# Addiitional releated packages:
# * NumPy: the fundamental package for scientific computing
# * matplotlib: the most popular Python library for producing plots and other 2D data visualizations
# * pandas: a library providing high-performance, easy-to-use data structures and data analysis tools
# * SciPy: a collection of packages addressing a number of different standard problem domains in scientific computing
# * sklearn: machine learning in Python

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('~/Desktop/PythonLearning/City_of_Burlington_Property_Details.csv')

# %% [markdown]
# replacing vaues with NaN, Suppose the letter included is 'g':
#
# cchs = pd.read_csv("cchs2012.csv", header=0, na_values=['g'])
#
# If the data contains missing data indicated by 'NA', you can read the data in as follows:
#
# cchs = pd.read_csv("cchs2012.csv", header=0, na_values=['NA'])

# %%
# Checks correlation of the dataframe, specify a column in the parenthesis to check against a specific variable
df.corr()

# Display the top 5 rows (including the column names)
df.head(5)

# Lists summary info of datafram including count of non-null elements, data type, memory useage and range index
df.info()

# Count of number of rows and columns (in that order) ex: (24,12)
#df.shape()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10832 entries, 0 to 10831
# Data columns (total 38 columns):
# AccountNumber            10832 non-null int64
# ParcelID                 10832 non-null object
# SpanNumber               10832 non-null object
# StreetNumber             10827 non-null object
# AlternateNumber          1074 non-null object
# StreetName               10832 non-null object
# Unit                     2076 non-null object
# CuO1LastName             10831 non-null object
# CuO1FirstName            8519 non-null object
# CuO2LastName             5633 non-null object
# CuO2FirstName            5107 non-null object
# CuO3LastName             572 non-null object
# CuO3FirstName            461 non-null object
# LandUse                  10832 non-null object
# CurrentAcres             10832 non-null float64
# TotalGrossArea           10832 non-null int64
# FinishedArea             10832 non-null float64
# CurrentValue             10832 non-null float64
# CurrentLandValue         10832 non-null int64
# CurrentYardItemsValue    10832 non-null int64
# CurrentBuildingValue     10832 non-null float64
# BuildingType             10431 non-null object
# HeatFuel                 10339 non-null object
# HeatType                 10409 non-null object
# Grade                    10431 non-null object
# YearBlt                  10832 non-null int64
# SaleDate                 4636 non-null object
# SalePrice                10832 non-null int64
# LegalReference           10832 non-null object
# GrantorLastName          4635 non-null object
# NumofRooms               10832 non-null int64
# NumofBedrooms            10832 non-null int64
# Baths                    10832 non-null object
# NumofUnits               10832 non-null int64
# ZoningCode               10777 non-null object
# Foundation               10382 non-null object
# Depreciation             10832 non-null float64
# PropertyCenterPoint      10615 non-null object
# dtypes: float64(5), int64(9), object(24)
# memory usage: 3.1+ MB

# %%
#Just pull a specific column
df['LandUse'].head(4)
# Out:
# 1860    Commercial Land
# 9583     Partial Exempt
# 3519             Exempt
# 7688         Commercial
# Name: LandUse, dtype: object

# %%
df['LandUse'].value_counts()
# Out:
# Single Family                   5176
# Residential Condo               2150
# 2 Family                        1041
# 3 Family                         369
# Apartments 5+Units               367
# Commercial                       299
# Exempt                           286
# 4 Family                         239
# Res. Vacant Land                 235
# Commercial and Residential       158
# Mobile Home                      117
# Exempt Land                      112
# Commercial Condo                  91
# Seasonal home                     45
# Partial Exempt                    43
# Commercial Land                   34
# Industrial                        22
# Exempt Utility                    11
# Mobile Home w/Land                 8
# RESIDENTAL APT CONDO               6
# Utility Electric                   6
# Farmland                           6
# Utility Other                      4
# Industrial Land                    3
# Farm                               2
# Commercial/Residential Condo       1
# Cable TV personal property         1
# Name: LandUse, dtype: int64

# %%
# List unique values in a DataFrame column
pd.unique(df.NumofUnits.ravel())
# Out:
# array([  0,   1,   2,   4,  13,   3,   6,   5,  19,  44,  37, 123,   7,
#         49,   9,  61,  11,  10,   8, 109,  21,  16, 401,  26,  51,  33,
#         27,  12,  17,  41,  47, 125,  23,  54,  25, 375,  39, 605,  80,
#        112,  42,  52,  24,  55, 462,  14, 140,  15, 161,  20,  18,  76,
#        258,  22,  34,  36,  31,  82,  28, 396,  81, 581, 205, 460, 303,
#         29, 227, 128,  84, 144, 311, 216,  66, 160,  59,  56,  65, 225,
#        117, 338, 220,  43,  35,  40, 908,  30, 679, 150], dtype=int64)

# %%
# Get quick count of rows in a DataFrame
len(df.index)
# Out:
# 10832

# %% [markdown]
# Numpy
# -----------
# Quick Mathmatical Functions

# %%
# Mathmatical description and statistics of all numerical columns
df.describe()

# Returns a count of not null elements in each column (much like df.info)
df.count()

# Returns a list of numerical columns with total sum
df.sum()

# Returns a list of numerical columns with standard deviation
df.std()

# Returns a list of numerical columns with mean
df.mean()

# Returns a list of numerical columns with median
df.median()
# Out:
# AccountNumber              5538.50000
# CurrentAcres                  0.15152
# TotalGrossArea             3174.00000
# FinishedArea               1602.00000
# CurrentValue             236150.00000
# CurrentLandValue          91600.00000
# CurrentYardItemsValue         0.00000
# CurrentBuildingValue     147600.00000
# YearBlt                    1950.00000
# SalePrice                     0.00000
# NumofRooms                    6.00000
# NumofBedrooms                 3.00000
# NumofUnits                    1.00000
# Depreciation                  0.24000
# dtype: float64

# %%
# Get length of data in a DataFrame column
dflen = df.StreetNumber.str.len()
dflen.head()
# Out:
# 0    3.0
# 1    2.0
# 2    2.0
# 3    3.0
# 4    2.0
# Name: StreetNumber, dtype: float64

# %% [markdown]
# Creating Group By Lists
# ------------

# %%
df[["HeatType", "NumofRooms"]].groupby(['HeatType'], as_index=False).count()
#df[["HeatType", "NumofRooms"]].groupby(['HeatType'], as_index=False).mean()
#df[["HeatType", "NumofRooms"]].groupby(['HeatType'], as_index=False).median()
# Out:
#         HeatType  NumofRooms
# 0       ELECTRIC         307
# 1   H WATER/RADI          52
# 2      HEAT PUMP          69
# 3        HOT AIR        4240
# 4      HOT WATER        4482
# 5           HVAC          80
# 6    RADIANT FLR          60
# 7     SPACE HEAT         823
# 8          STEAM         249
# 9        TYPICAL           6
# 10      UNHEATED          41

# %% [markdown]
# Numpy Percentiles
# ------------

# %%
# Returns percentile value for specificed column
np.percentile(df['TotalGrossArea'],25)

# Returns an array of specified percentiles for specificed column, it is in scientific notation because it is float
np.percentile(df['TotalGrossArea'],[0,25,50,100])
# Out:
# array([  0.00000000e+00,   2.31700000e+03,   3.17400000e+03,
#          2.54235100e+06])

# %%
# When doing it with an interger it will not have scientific notation
np.percentile(df['YearBlt'],[0,25,50,100])
# Out:
# array([    0.,  1905.,  1950.,  2015.])

# %% [markdown]
# Binning
# ------

# %%
# You can bin at whatever cut you want, in this case it is percentiles
yearperc = np.percentile(df['YearBlt'],[0,25,50,100])

# This creates a new column, but you can also overwrite the data already there
df['YearBltBin'] = pd.cut(df['YearBlt'], yearperc)
df.head(3)
# Out:
#    AccountNumber       ParcelID     SpanNumber StreetNumber AlternateNumber  \
# 0           7502  049-3-187-000  114-035-17502          227             NaN
# 1          10680  043-3-085-001  114-035-20680           53             NaN
# 2           9512  057-1-013-000  114-035-19512           47             NaN
#
#    StreetName Unit        CuO1LastName CuO1FirstName CuO2LastName  \
# 0  COLLEGE ST  NaN            CITY DPW           NaN          NaN
# 1     WARD ST  NaN             EMERSON     DEBORAH A      EMERSON
# 2    SEARS LN  NaN  CITY OF BURLINGTON           NaN          NaN
#
#        ...      GrantorLastName NumofRooms NumofBedrooms  Baths  NumofUnits  \
# 0      ...                  NaN          0             0  0 / 0           0
# 1      ...                  NaN          6             3  1 / 0           1
# 2      ...                  NaN          0             0  0 / 0           0
#
#    ZoningCode  Foundation  Depreciation   PropertyCenterPoint    YearBltBin
# 0          DT         NaN           0.0  (-73.2105, 44.47668)           NaN
# 1         NaN           C           0.3                   NaN  (1905, 1950]
# 2         ELM         NaN           0.0  (-73.2168, 44.45806)           NaN
#
# [3 rows x 39 columns]

# %% [markdown]
# Subsetting
# ------------
# Return subsets of a dateframe

# %%
# Returns first row through the specified number of rows, in this case 50
subdf = df[:50]
subdf.shape
# Out:
# (50, 39)

# %%
# Returns from row 100 through too the end of the dataframe
subdf = df[100:]
subdf.shape
# Out:
# (10732, 39)

# %%
# Select from DataFrame using criteria from multiple columns
# (use `|` instead of `&` to do an OR)
newdf = df[(df['NumofRooms'] > 1) & (df['Foundation'] == 'C')]
newdf.head(3)
# Out:
#       AccountNumber       ParcelID     SpanNumber StreetNumber  \
# 1860           5333  044-4-033-000  114-035-15333           75
# 2295           7815  050-1-009-000  114-035-17815          368
# 583            4865  044-2-005-000  114-035-14865           16
#
#      AlternateNumber StreetName Unit              CuO1LastName CuO1FirstName  \
# 1860             NaN  CHERRY ST  NaN  btc mall associates, llc           NaN
# 2295             NaN    MAIN ST  NaN      alpha lambda chapter           NaN
# 583              NaN  CHERRY ST  NaN  cssl limited partnership           NaN
#
#            CuO2LastName      ...      GrantorName NumofRooms NumofBedrooms  \
# 1860                NaN      ...              NaN        605           605
# 2295  HOUSE ASSOCIATION      ...              NaN        289            17
# 583                 NaN      ...              NaN        221           112
#
#      BathsCombined  NumofUnits  ZoningCode  Foundation  Depreciation  \
# 1860         0 / 0         605           D           C         1.000
# 2295         2 / 1          17          RH           C         0.215
# 583        108 / 6         109           D           C         0.162
#
#        PropertyCenterPoint    YearBltBin
# 1860   (-73.215, 44.47894)  (1950, 2015]
# 2295  (-73.2043, 44.47671)  (1950, 2015]
# 583   (-73.2178, 44.47959)  (1950, 2015]
#
# [3 rows x 38 columns]

# %%
# pixdf = df.ix[:,'StreetNumber':'StreetName']
ixdf = df.ix[:,'StreetNumber':'StreetName']
ixdf.head(5)
# Out:
#      StreetNumber AlternateNumber        StreetName
# 1860           75             NaN         CHERRY ST
# 9583          225             NaN  SOUTH WILLARD ST
# 3519          230             NaN        ST PAUL ST
# 7688           80             NaN        ST PAUL ST
# 8857          227             NaN  SOUTH WILLARD ST

# %%
# Grab DataFrame rows where column has certain values
valuelist = ['4']
dfselect = df[df.NumofUnits.isin(valuelist)]
dfselect.head(2)
# Out:
# Empty DataFrame
# Columns: [AccountNumber, ParcelID, SpanNumber, StreetNumber, AlternateNumber, StreetName, Unit, CuO1LastName, CuO1FirstName, CuO2LastName, CuO2FirstName, CuO3LastName, CuO3FirstName, LandUse, CurrentAcres, TotalGrossArea, FinishedArea, CurrentValue, CurrentLandValue, CurrentYardItemsValue, CurrentBuildingValue, BuildingType, HeatFuel, HeatType, Grade, YearBlt, SaleDate, SalePrice, GrantorName, NumofRooms, NumofBedrooms, BathsCombined, NumofUnits, ZoningCode, Foundation, Depreciation, PropertyCenterPoint, YearBltBin]
# Index: []
#
# [0 rows x 38 columns]

# %%
# Grab DataFrame rows where column doesn't have certain values
valuelist = ['4', '13', '6']
dfnotselect = df[~df.NumofUnits.isin(valuelist)]
dfnotselect.head(2)
# Out:
#    AccountNumber       ParcelID     SpanNumber StreetNumber AlternateNumber  \
# 0           7502  049-3-187-000  114-035-17502          227             NaN
# 1          10680  043-3-085-001  114-035-20680           53             NaN
#
#    StreetName Unit CuO1LastName CuO1FirstName CuO2LastName      ...       \
# 0  COLLEGE ST  NaN     CITY DPW           NaN          NaN      ...
# 1     WARD ST  NaN      EMERSON     DEBORAH A      EMERSON      ...
#
#   GrantorLastName NumofRooms NumofBedrooms  Baths  NumofUnits  ZoningCode  \
# 0             NaN          0             0  0 / 0           0          DT
# 1             NaN          6             3  1 / 0           1         NaN
#
#    Foundation  Depreciation   PropertyCenterPoint    YearBltBin
# 0         NaN           0.0  (-73.2105, 44.47668)           NaN
# 1           C           0.3                   NaN  (1905, 1950]
#
# [2 rows x 39 columns]

# %% [markdown]
# Subsetting Not Null/Null
# -------------

# %%
# Grab DataFrame rows where specific column is null
nulldf = df[df['AlternateNumber'].isnull()]
nulldf.head(3)

#Alternative way to write it
nulldf = df[pd.isnull(df['AlternateNumber'])]
nulldf.head(3)
# Out:
#    AccountNumber       ParcelID     SpanNumber StreetNumber AlternateNumber  \
# 0           7502  049-3-187-000  114-035-17502          227             NaN
# 1          10680  043-3-085-001  114-035-20680           53             NaN
# 2           9512  057-1-013-000  114-035-19512           47             NaN
#
#    StreetName Unit        CuO1LastName CuO1FirstName CuO2LastName  \
# 0  COLLEGE ST  NaN            CITY DPW           NaN          NaN
# 1     WARD ST  NaN             EMERSON     DEBORAH A      EMERSON
# 2    SEARS LN  NaN  CITY OF BURLINGTON           NaN          NaN
#
#        ...      GrantorLastName NumofRooms NumofBedrooms  Baths  NumofUnits  \
# 0      ...                  NaN          0             0  0 / 0           0
# 1      ...                  NaN          6             3  1 / 0           1
# 2      ...                  NaN          0             0  0 / 0           0
#
#    ZoningCode  Foundation  Depreciation   PropertyCenterPoint    YearBltBin
# 0          DT         NaN           0.0  (-73.2105, 44.47668)           NaN
# 1         NaN           C           0.3                   NaN  (1905, 1950]
# 2         ELM         NaN           0.0  (-73.2168, 44.45806)           NaN
#
# [3 rows x 39 columns]

# %%
# Grab DataFrame rows where specific column notnull
notnulldf = df[df['AlternateNumber'].notnull()]
notnulldf.head(3)
# Out:
#     AccountNumber       ParcelID     SpanNumber StreetNumber AlternateNumber  \
# 21          10714  054-3-001-143  114-035-20714          384             392
# 25           6052  045-2-075-000  114-035-16052           47              49
# 48           5507  044-4-185-000  114-035-15507          247             249
#
#            StreetName Unit           CuO1LastName CuO1FirstName  \
# 21  SOUTH PROSPECT ST  NaN  UNIVERSITY OF VERMONT           NaN
# 25          GREENE ST  NaN                   LANG         ANN G
# 48           PEARL ST  NaN          247 PEARL LLC           NaN
#
#                   CuO2LastName      ...      GrantorLastName NumofRooms  \
# 21  STATE AGRICULTURAL COLLEGE      ...                  NaN          0
# 25                         NaN      ...                  NaN          8
# 48                         NaN      ...                  NaN          0
#
#    NumofBedrooms  Baths  NumofUnits  ZoningCode  Foundation  Depreciation  \
# 21             0  1 / 2           2         NaN           C         0.399
# 25             4  2 / 0           2          RM          BS         0.270
# 48             0  1 / 6           3          RH          BS         0.475
#
#      PropertyCenterPoint    YearBltBin
# 21                   NaN  (1905, 1950]
# 25  (-73.2078, 44.48206)     (0, 1905]
# 48  (-73.2087, 44.48001)     (0, 1905]
#
# [3 rows x 39 columns]

# %% [markdown]
# Replacing Column Names
# ---------------

# %%
# Rename several DataFrame columns
df = df.rename(columns = {
    'Baths':'BathsCombined',
    'GrantorLastName':'GrantorName',
})
df.head(1)
# Out:
#       AccountNumber       ParcelID     SpanNumber StreetNumber  \
# 1860           5333  044-4-033-000  114-035-15333           75
#
#      AlternateNumber StreetName Unit              CuO1LastName CuO1FirstName  \
# 1860             NaN  CHERRY ST  NaN  btc mall associates, llc           NaN
#
#      CuO2LastName      ...      GrantorName NumofRooms NumofBedrooms  \
# 1860          NaN      ...              NaN        605           605
#
#      BathsCombined  NumofUnits  ZoningCode  Foundation  Depreciation  \
# 1860         0 / 0         605           D           C           1.0
#
#       PropertyCenterPoint    YearBltBin
# 1860  (-73.215, 44.47894)  (1950, 2015]
#
# [1 rows x 38 columns]

# %%
# Even more fancy DataFrame column re-naming
# lower-case all DataFrame column names (for example)
#df.rename(columns=lambda x: x.split('.')[-1], inplace=True)
# Loop through rows in a DataFrame
# (if you must)
#for index, row in df.iterrows():
#    print index, row['some column']

# %% [markdown]
# Replace Values
# ------

# %%
# Replace one value with another for the whole dataframe
dfreplace = df.replace("SOUTH WILLARD ST","S Willard Street")
dfreplace.head(5)
# Out:
#       AccountNumber       ParcelID     SpanNumber StreetNumber  \
# 1860           5333  044-4-033-000  114-035-15333           75
# 9583           7871  050-1-066-000  114-035-17871          225
# 3519           7583  049-4-059-000  114-035-17583          230
# 7688           7249  049-3-023-001  114-035-17249           80
# 8857           7856  050-1-051-000  114-035-17856          227
#
#      AlternateNumber        StreetName Unit                  CuO1LastName  \
# 1860             NaN         CHERRY ST  NaN      btc mall associates, llc
# 9583             NaN  S Willard Street  NaN        champlain college inc.
# 3519             NaN        ST PAUL ST  NaN  burlington housing authority
# 7688             NaN        ST PAUL ST  NaN       burlington savings bank
# 8857             NaN  S Willard Street  NaN        champlain college inc.
#
#      CuO1FirstName       CuO2LastName      ...      GrantorName NumofRooms  \
# 1860           NaN                NaN      ...              NaN        605
# 9583           NaN                NaN      ...              NaN        400
# 3519           NaN  BHA DECKER TOWERS      ...              NaN        371
# 7688           NaN                NaN      ...              NaN        311
# 8857           NaN                NaN      ...              NaN        289
#
#      NumofBedrooms BathsCombined  NumofUnits  ZoningCode  Foundation  \
# 1860           605         0 / 0         605           D           C
# 9583             0        11 / 0          20           I          BS
# 3519           106       161 / 1         161          RM           S
# 7688             0         0 / 0         311           D           S
# 8857             0         8 / 2          25           I          BS
#
#       Depreciation   PropertyCenterPoint    YearBltBin
# 1860        1.0000   (-73.215, 44.47894)  (1950, 2015]
# 9583        0.3000  (-73.2063, 44.47431)     (0, 1905]
# 3519        0.2782   (-73.213, 44.47275)  (1950, 2015]
# 7688        0.2775  (-73.2135, 44.47762)  (1950, 2015]
# 8857        0.3000  (-73.2057, 44.47373)     (0, 1905]
#
# [5 rows x 38 columns]

# %%
#This can also be done with multiple changes in one line
dfreplace = df.replace({"COLLEGE ST":"College Street",
                        "CHERRY ST":"Cherry Street"})
dfreplace.head(3)

# %%
#train_df.loc[train_df["Title"] == "Mlle", "Title"] = 'Miss'

# %%
# Set DataFrame column values based on other column values NOT WORKING
df.loc[(df['AccountNumber'] == 5333) & 
       (df['StreetNumber'] == 75), 'AlternateNumber'] = 1
df
# Out:
#        AccountNumber       ParcelID     SpanNumber StreetNumber  \
# 1860            5333  044-4-033-000  114-035-15333           75
# 9583            7871  050-1-066-000  114-035-17871          225
# 3519            7583  049-4-059-000  114-035-17583          230
# 7688            7249  049-3-023-001  114-035-17249           80
# 8857            7856  050-1-051-000  114-035-17856          227
# 2295            7815  050-1-009-000  114-035-17815          368
# 4868            2488  028-3-140-001  114-035-12488           72
# 9008            7818  050-1-012-000  114-035-17818          396
# 583             4865  044-2-005-000  114-035-14865           16
# 8347            7153  049-1-136-000  114-035-17153          101
# 6602            7957  050-2-017-000  114-035-17957          232
# 8999            6262  045-3-034-000  114-035-16262          214
# 8454           10755  044-2-146-000  114-035-20755           25
# 8090             499  023-4-026-001  114-035-10499           43
# 899             4881  044-2-019-000  114-035-14881           10
# 6399            8265  050-4-098-376  114-035-18265           67
# 10596            534  023-4-064-001  114-035-10534           98
# 10081          10735  045-3-140-003  114-035-20735          130
# 3196            7104  049-1-110-000  114-035-17104          101
# 9962           10566  043-3-208-001  114-035-20566          300
# 4019            7160  049-1-143-001  114-035-17160           60
# 4443            8424  053-3-058-000  114-035-18424          397
# 2429            7189  049-2-028-000  114-035-17189          234
# 6547           11093  044-2-147-001  114-035-52634           41
# 1828           11081  028-4-006-001  114-035-12506         1195
# 1004           11078  028-4-005-000  114-035-52559         1201
# 1327            8115  050-3-021-328  114-035-18115           75
# 7484            4885  044-2-023-000  114-035-14885           80
# 664             7194  049-2-032-000  114-035-17194           57
# 1303           11080  028-4-006-005  114-035-52562         1191
# ...              ...            ...            ...          ...
# 10318          11226  054-2-157-000  114-035-21226           69
# 10321           4386  043-3-188-000  114-035-14386           31
# 10359           3642  038-2-006-000  114-035-13642          601
# 10361           4635  044-1-177-000  114-035-20610           32
# 10365           7829  050-1-022-000  114-035-17829          174
# 10381           4661  044-1-204-000  114-035-20629           21
# 10413           7329  049-3-095-009  114-035-17329          131
# 10455           9102  054-3-002-210  114-035-19102          448
# 10484          10684  030-3-018-000  114-035-20684          465
# 10497          10600  044-1-067-000  114-035-20600          221
# 10503            468  023-3-169-000  114-035-10468           88
# 10506             16  020-3-007-000  114-035-10016         3163
# 10512           7317  049-3-091-000  114-035-17317          147
# 10534           4822  044-1-352-000  114-035-20608           64
# 10576           6371  045-4-020-000  114-035-16371           96
# 10669           4141  040-2-112-000  114-035-14141          287
# 10681          10756  044-2-147-000  114-035-20756           41
# 10692          11209  027-4-095-000  114-035-52790           78
# 10701           4118  040-2-081-000  114-035-14118          593
# 10719          10906  044-2-145-001  114-035-20906           35
# 10784           5348  044-4-045-000  114-035-15348           31
# 10787           8310  053-1-002-000  114-035-18310          501
# 10790           3556  034-2-009-000  114-035-13556          674
# 10821            551  024-1-017-000  114-035-10551          124
# 4944           10540  049-3-095-606  114-035-20540          131
# 10283           7737  049-4-193-001  114-035-17737          283
# 10349           4613  044-1-152-000  114-035-14613          118
# 5857            4800  044-1-330-000  114-035-14800          120
# 6037            4031  039-4-256-000  114-035-14031          118
# 3278            7585  049-4-061-000  114-035-17585          322
#
#       AlternateNumber          StreetName       Unit  \
# 1860              NaN           CHERRY ST        NaN
# 9583              NaN    SOUTH WILLARD ST        NaN
# 3519              NaN          ST PAUL ST        NaN
# 7688              NaN          ST PAUL ST        NaN
# 8857              NaN    SOUTH WILLARD ST        NaN
# 2295              NaN             MAIN ST        NaN
# 4868              NaN        HEINEBERG RD        NaN
# 9008              NaN             MAIN ST        NaN
# 583               NaN           CHERRY ST        NaN
# 8347              NaN          COLLEGE ST        NaN
# 6602              NaN    SOUTH WILLARD ST        NaN
# 8999              NaN   NORTH PROSPECT ST        NaN
# 8454              NaN           CHERRY ST        NaN
# 8090              NaN       STARR FARM RD        NaN
# 899                20  NORTH CHAMPLAIN ST        NaN
# 6399              NaN            SPEAR ST        NaN
# 10596             NaN       STARR FARM RD        NaN
# 10081             NaN        MANSFIELD AV     Unit 3
# 3196              NaN             MAIN ST        NaN
# 9962              NaN             LAKE ST        NaN
# 4019              NaN          BATTERY ST        NaN
# 4443              NaN          ST PAUL ST        NaN
# 2429              NaN  SOUTH CHAMPLAIN ST        NaN
# 6547               55           CHERRY ST        NaN
# 1828              NaN            NORTH AV        NaN
# 1004              NaN            NORTH AV        NaN
# 1327              NaN       COLCHESTER AV        NaN
# 7484               90            PEARL ST        NaN
# 664                61            MAPLE ST        NaN
# 1303              NaN            NORTH AV        NaN
# ...               ...                 ...        ...
# 10318             NaN            LEDGE RD        NaN
# 10321             NaN            NORTH AV        NaN
# 10359             NaN             LAKE ST        NaN
# 10361             NaN            CEDAR ST        NaN
# 10365             NaN    SOUTH WILLARD ST        NaN
# 10381             NaN       LAFOUNTAIN ST        NaN
# 10413             NaN             MAIN ST  Unit C-2F
# 10455             NaN   SOUTH PROSPECT ST        NaN
# 10484             NaN  APPLETREE POINT RD        NaN
# 10497             NaN             PARK ST        NaN
# 10503             NaN       NORTH VIEW DR        NaN
# 10506             NaN            NORTH AV        NaN
# 10512             151             MAIN ST        NaN
# 10534             NaN           MURRAY ST        NaN
# 10576             NaN       COLCHESTER AV        NaN
# 10669             289   NORTH WINOOSKI AV        NaN
# 10681             NaN           CHERRY ST        NaN
# 10692             NaN  STANIFORD FARMS RD        NaN
# 10701             595        RIVERSIDE AV        NaN
# 10719             NaN           CHERRY ST        NaN
# 10784             NaN          ELMWOOD AV        NaN
# 10787             NaN             PINE ST        NaN
# 10790             NaN            NORTH AV        NaN
# 10821             NaN       PLATTSBURG AV        NaN
# 4944              NaN             MAIN ST   Unit 606
# 10283             NaN      SOUTH UNION ST     Unit 1
# 10349             NaN            NORTH ST        NaN
# 5857              NaN  NORTH CHAMPLAIN ST        NaN
# 6037              122        ARCHIBALD ST        NaN
# 3278              324          ST PAUL ST        NaN
#
#                          CuO1LastName        CuO1FirstName  \
# 1860         btc mall associates, llc                  NaN
# 9583           champlain college inc.                  NaN
# 3519     burlington housing authority                  NaN
# 7688          burlington savings bank                  NaN
# 8857           champlain college inc.                  NaN
# 2295             alpha lambda chapter                  NaN
# 4868     cathedral square corporation                  NaN
# 9008           champlain college inc.                  NaN
# 583          cssl limited partnership                  NaN
# 8347     burlington housing authority                  NaN
# 6602           champlain college inc.                  NaN
# 8999            synagogue corporation                  NaN
# 8454   burlington harbor hotel gp llc                  NaN
# 8090                ventas realty l p                  NaN
# 899      burlington housing authority                  NaN
# 6399            university of vermont                  NaN
# 10596          starr farm partnership                  NaN
# 10081     mcauley square bond ltd ptr                  NaN
# 3196          catamount/van ness, llc                  NaN
# 9962   waterfront housing lp (leasee)                  NaN
# 4019   diamondrock burlington owner l                  NaN
# 4443        trono construction co inc                  NaN
# 2429      bobbin mill limited partner                  NaN
# 6547             41 cherry street llc                  NaN
# 1828    schoolhouse-lofts housing llc                  NaN
# 1004        avenue apartments housing                  NaN
# 1327            university of vermont                  NaN
# 7484                             bove            RICHARD J
# 664             wharf lane housing lp                  NaN
# 1303           thayer commons housing                  LLC
# ...                               ...                  ...
# 10318                      city parks                  NaN
# 10321                           smith           CYNTHIA W.
# 10359              city of burlington                  NaN
# 10361         champlain housing trust                  NaN
# 10365          champlain college inc.                  NaN
# 10381         champlain housing trust                  NaN
# 10413                       drinkwine             URSULA M
# 10455           university of vermont                  NaN
# 10484                         senecal            CHERYL L.
# 10497         champlain housing trust                  NaN
# 10503                      tabailloux          KATHERINE L
# 10506                          shappy               JOHN A
# 10512           flynn est j j trustee                  NaN
# 10534         champlain housing trust                  NaN
# 10576                        clifford         PATRICK P MD
# 10669  burlington dept of parks & rec                  NaN
# 10681                  city treasurer                  NaN
# 10692            staniford farms, llc                  NaN
# 10701            related property llc                  NaN
# 10719            westlake parking llc                  NaN
# 10784              spectrum youth and  FAMILY SERVICES INC
# 10787              maltex partnership                  NaN
# 10790                             roy              LEOLA E
# 10821         champlain housing trust                  NaN
# 4944                           vaghin            ANASTASIA
# 10283                          graham            CHRISTINE
# 10349                      bissonette                SHANE
# 5857   committee on temporary shelter                  NaN
# 6037                        bpawg llc                  NaN
# 3278          champlain housing trust                  NaN
#
#                      CuO2LastName      ...       \
# 1860                          NaN      ...
# 9583                          NaN      ...
# 3519            BHA DECKER TOWERS      ...
# 7688                          NaN      ...
# 8857                          NaN      ...
# 2295            HOUSE ASSOCIATION      ...
# 4868                          NaN      ...
# 9008                          NaN      ...
# 583                           NaN      ...
# 8347                          NaN      ...
# 6602                          NaN      ...
# 8999                          NaN      ...
# 8454                          NaN      ...
# 8090                          NaN      ...
# 899                           NaN      ...
# 6399   STATE AGRICULTURAL COLLEGE      ...
# 10596   STARR FARM NURSING CENTER      ...
# 10081                         NaN      ...
# 3196                          NaN      ...
# 9962                          NaN      ...
# 4019                          NaN      ...
# 4443                          NaN      ...
# 2429                          NaN      ...
# 6547                          NaN      ...
# 1828                          NaN      ...
# 1004                          NaN      ...
# 1327   STATE AGRICULTURAL COLLEGE      ...
# 7484                         BOVE      ...
# 664                           NaN      ...
# 1303                          NaN      ...
# ...                           ...      ...
# 10318                         NaN      ...
# 10321                         NaN      ...
# 10359                         NaN      ...
# 10361                         NaN      ...
# 10365                         NaN      ...
# 10381                         NaN      ...
# 10413                         NaN      ...
# 10455  STATE AGRICULTURAL COLLEGE      ...
# 10484                 SENECAL JR.      ...
# 10497                         NaN      ...
# 10503                         NaN      ...
# 10506                      SHAPPY      ...
# 10512                         NaN      ...
# 10534                         NaN      ...
# 10576                       BLAKE      ...
# 10669                         NaN      ...
# 10681                         NaN      ...
# 10692                         NaN      ...
# 10701                         NaN      ...
# 10719                         NaN      ...
# 10784                         NaN      ...
# 10787         THE MALTEX BUILDING      ...
# 10790    LEOLA E ROY REVOCABLE TR      ...
# 10821                         NaN      ...
# 4944                          NaN      ...
# 10283                         NaN      ...
# 10349                         NaN      ...
# 5857                          NaN      ...
# 6037                          NaN      ...
# 3278                          NaN      ...
#
#                               GrantorName NumofRooms NumofBedrooms  \
# 1860                                  NaN        605           605
# 9583                                  NaN        400             0
# 3519                                  NaN        371           106
# 7688                                  NaN        311             0
# 8857                                  NaN        289             0
# 2295                                  NaN        289            17
# 4868                                  NaN        257            93
# 9008                                  NaN        256             0
# 583                                   NaN        221           112
# 8347                                  NaN        205            75
# 6602                                  NaN        196             0
# 8999                                  NaN        183            61
# 8454                                  NaN        161           161
# 8090                                  NaN        160           320
# 899                                   NaN        158            56
# 6399                                  NaN        152           151
# 10596                                 NaN        150           150
# 10081                                 NaN        146            73
# 3196                       RF COOPER LLC,        145           139
# 9962                                  NaN        144            68
# 4019                                  NaN        141           256
# 4443                                  NaN        132            60
# 2429                                  NaN        129            56
# 6547                                  NaN        127           127
# 1828                                  NaN        126            41
# 1004                                  NaN        126            57
# 1327                                  NaN        126           125
# 7484                                  NaN        123            54
# 664                                   NaN        113            41
# 1303                                  NaN        112            47
# ...                                   ...        ...           ...
# 10318                                 NaN          0             0
# 10321                                 NaN          0             0
# 10359                                 NaN          0             0
# 10361                                 NaN          0             0
# 10365                                 NaN          0             0
# 10381                                 NaN          0             0
# 10413                                 NaN          0             0
# 10455                                 NaN          0             0
# 10484                   Chase, Brianne E.          0             0
# 10497                                 NaN          0             0
# 10503                                 NaN          0             0
# 10506                                 NaN          0             0
# 10512                                 NaN          0             0
# 10534                                 NaN          0             0
# 10576                                 NaN          0             0
# 10669                                 NaN          0             0
# 10681                                 NaN          0             0
# 10692                       WICK,HILTON A          0             0
# 10701                                 NaN          0             0
# 10719  WESTLAKE RESICENTIAL PARTNERS LLC,          0             0
# 10784                                 NaN          0             0
# 10787                                 NaN          0             0
# 10790                                 NaN          0             0
# 10821                                 NaN          0             0
# 4944           CHRISTOPHER HALL REV TRUST          0             2
# 10283                       MARTIN ALLEN,          0             2
# 10349               REGINALD NELSON BURBO          0             4
# 5857                                  NaN          0             5
# 6037                                  NaN          0             8
# 3278                                  NaN          0            15
#
#       BathsCombined  NumofUnits  ZoningCode  Foundation  Depreciation  \
# 1860          0 / 0         605           D           C        1.0000
# 9583         11 / 0          20           I          BS        0.3000
# 3519        161 / 1         161          RM           S        0.2782
# 7688          0 / 0         311           D           S        0.2775
# 8857          8 / 2          25           I          BS        0.3000
# 2295          2 / 1          17          RH           C        0.2150
# 4868         82 / 1          82          RL           S        0.2720
# 9008          5 / 2          16          RH          BS        0.6500
# 583         108 / 6         109           D           C        0.1620
# 8347         65 / 0          65           D          BS        0.2010
# 6602          5 / 1          14           I          BS        0.1000
# 8999         61 / 2          61          RL           C        0.1230
# 8454        161 / 4         161           D           C        0.0000
# 8090         80 / 4         160          RL           C        0.1990
# 899          51 / 1          51          DT           S        0.2280
# 6399         32 / 3         303           I           C        0.2280
# 10596        81 / 4         150          RL           C        0.0900
# 10081        55 / 1          55           I           C        0.3695
# 3196        146 / 0         140          DT           C        0.0000
# 9962         40 / 2          40         RMW           C        0.0030
# 4019        256 / 4         258           D           C        0.1460
# 4443         36 / 0          36          RM           S        0.1180
# 2429         35 / 0          52          RM           S        0.1380
# 6547        128 / 4         128           D           C        0.0000
# 1828         39 / 0          39         NAC           C        0.0000
# 1004         33 / 0          33         NAC           C        0.0000
# 1327         15 / 6         125           I          BS        0.3000
# 7484         34 / 8          34          DT           C        0.0180
# 664          37 / 0          37         BST           S        0.0740
# 1303         48 / 0          47         NAC           C        0.0000
# ...             ...         ...         ...         ...           ...
# 10318         0 / 0           0         NaN         NaN        0.0000
# 10321         0 / 0           0         RMW         NaN        0.0000
# 10359         0 / 0           0        DWPT         NaN        0.0000
# 10361         0 / 0           0          RM         NaN        0.0000
# 10365         1 / 2           0           I           C        0.2490
# 10381         0 / 0           0          RM         NaN        0.0000
# 10413         0 / 1           0          DT          BS        0.2240
# 10455         0 / 0           0           I         NaN        0.0000
# 10484         0 / 0           0         NaN         NaN        0.0000
# 10497         0 / 0           0          RM         NaN        0.0000
# 10503         0 / 0           0        RCOC         NaN        0.0000
# 10506         0 / 0           0         RLW         NaN        0.0000
# 10512         0 / 3           0          DT           C        0.2010
# 10534         0 / 0           0          RM         NaN        0.0000
# 10576         0 / 5           0           I          BS        0.4050
# 10669         0 / 0           0         NMU         NaN        0.2000
# 10681         0 / 0           0           D         NaN        0.0000
# 10692         0 / 0           0         RLW         NaN        0.0000
# 10701         0 / 0           0         NMU         NaN        0.0000
# 10719         0 / 0           0         NaN         NaN        0.0000
# 10784         1 / 1           0          RH          BS        0.3000
# 10787         0 / 0           0         ELM         NaN        0.0000
# 10790         0 / 0           0          RL         NaN        0.0000
# 10821         0 / 0           0          RL         NaN        0.0000
# 4944          1 / 0           1         NaN          BS        0.1500
# 10283         1 / 0           1          RL           C        0.2820
# 10349         2 / 0           1         NMU          CB        0.3000
# 5857          3 / 1           5          RM          BS        0.2894
# 6037          2 / 0           2         NMU          BS        0.3990
# 3278          4 / 1          15          RM          BS        0.0900
#
#         PropertyCenterPoint    YearBltBin
# 1860    (-73.215, 44.47894)  (1950, 2015]
# 9583   (-73.2063, 44.47431)     (0, 1905]
# 3519    (-73.213, 44.47275)  (1950, 2015]
# 7688   (-73.2135, 44.47762)  (1950, 2015]
# 8857   (-73.2057, 44.47373)     (0, 1905]
# 2295   (-73.2043, 44.47671)  (1950, 2015]
# 4868   (-73.2474, 44.51078)  (1950, 2015]
# 9008   (-73.2033, 44.47675)     (0, 1905]
# 583    (-73.2178, 44.47959)  (1950, 2015]
# 8347    (-73.216, 44.47672)     (0, 1905]
# 6602   (-73.2048, 44.47366)     (0, 1905]
# 8999   (-73.2006, 44.48722)  (1950, 2015]
# 8454   (-73.2182, 44.47876)  (1950, 2015]
# 8090   (-73.2603, 44.51576)  (1950, 2015]
# 899     (-73.217, 44.48069)  (1950, 2015]
# 6399   (-73.1966, 44.46945)  (1950, 2015]
# 10596  (-73.2638, 44.51692)  (1950, 2015]
# 10081   (-73.1981, 44.4849)  (1950, 2015]
# 3196   (-73.2153, 44.47551)     (0, 1905]
# 9962   (-73.2227, 44.48299)  (1950, 2015]
# 4019   (-73.2182, 44.47798)  (1950, 2015]
# 4443    (-73.212, 44.46825)  (1950, 2015]
# 2429   (-73.2161, 44.47247)     (0, 1905]
# 6547                    NaN  (1950, 2015]
# 1828                    NaN  (1905, 1950]
# 1004                    NaN  (1950, 2015]
# 1327   (-73.1956, 44.47718)     (0, 1905]
# 7484   (-73.2157, 44.48059)  (1950, 2015]
# 664    (-73.2174, 44.47321)  (1905, 1950]
# 1303                    NaN  (1950, 2015]
# ...                     ...           ...
# 10318                   NaN           NaN
# 10321  (-73.2219, 44.48279)           NaN
# 10359  (-73.2263, 44.48466)           NaN
# 10361  (-73.2163, 44.48594)           NaN
# 10365   (-73.205, 44.47537)  (1905, 1950]
# 10381  (-73.2156, 44.48533)           NaN
# 10413  (-73.2136, 44.47548)     (0, 1905]
# 10455  (-73.2001, 44.46786)           NaN
# 10484  (-73.2721, 44.50158)           NaN
# 10497  (-73.2197, 44.48674)           NaN
# 10503  (-73.2614, 44.52255)           NaN
# 10506   (-73.273, 44.52806)           NaN
# 10512  (-73.2132, 44.47564)  (1905, 1950]
# 10534  (-73.2158, 44.48432)           NaN
# 10576  (-73.1963, 44.48112)  (1905, 1950]
# 10669  (-73.2082, 44.48785)           NaN
# 10681  (-73.2173, 44.47858)           NaN
# 10692                   NaN           NaN
# 10701     (-73.2051, 44.49)           NaN
# 10719                   NaN           NaN
# 10784   (-73.214, 44.48132)     (0, 1905]
# 10787   (-73.2158, 44.4648)           NaN
# 10790  (-73.2328, 44.49844)           NaN
# 10821   (-73.2576, 44.5192)           NaN
# 4944   (-73.2136, 44.47548)  (1950, 2015]
# 10283  (-73.2091, 44.47207)     (0, 1905]
# 10349  (-73.2173, 44.48488)  (1905, 1950]
# 5857   (-73.2173, 44.48385)     (0, 1905]
# 6037    (-73.209, 44.48819)     (0, 1905]
# 3278   (-73.2123, 44.47078)     (0, 1905]
#
# [10832 rows x 38 columns]

# %%
#test_df["Fare"].fillna(test_df["Fare"].median(), inplace=True)
#train_df['Age']= train_df.Age.fillna(train_df.Age.interpolate(method='linear')) 
#train_df['Age']= train_df.Age.fillna(train_df.Age.mean())

# %%
# Clean up missing values in multiple DataFrame columns
df = df.fillna({
    'col1': 'No Street',
    'col2': '99.999',
})

# %%
# Delete column from DataFrame
del df['LegalReference']

# %% [markdown]
# Converting Types of Data
# --------------

# %%
# Converting a float to interger
df['FinishedArea'] = df['FinishedArea'].astype(int)

# %%
# Another way to change data type of DataFrame column
df.TotalGrossArea = df.TotalGrossArea.astype(np.int64)

# %% [markdown]
# Sorting
# ---------------

# %%
# Sort dataframe by multiple columns, 0 is descending from highest and 1 is ascending from lowest
df = df.sort_values(by=['NumofRooms','NumofBedrooms','NumofUnits'],ascending=[0,1,0])
df.head(3)
# Out:
#       AccountNumber       ParcelID     SpanNumber StreetNumber  \
# 1860           5333  044-4-033-000  114-035-15333           75
# 9583           7871  050-1-066-000  114-035-17871          225
# 3519           7583  049-4-059-000  114-035-17583          230
#
#      AlternateNumber        StreetName Unit                  CuO1LastName  \
# 1860             NaN         CHERRY ST  NaN      btc mall associates, llc
# 9583             NaN  SOUTH WILLARD ST  NaN        champlain college inc.
# 3519             NaN        ST PAUL ST  NaN  burlington housing authority
#
#      CuO1FirstName       CuO2LastName      ...      GrantorName NumofRooms  \
# 1860           NaN                NaN      ...              NaN        605
# 9583           NaN                NaN      ...              NaN        400
# 3519           NaN  BHA DECKER TOWERS      ...              NaN        371
#
#      NumofBedrooms BathsCombined  NumofUnits  ZoningCode  Foundation  \
# 1860           605         0 / 0         605           D           C
# 9583             0        11 / 0          20           I          BS
# 3519           106       161 / 1         161          RM           S
#
#       Depreciation   PropertyCenterPoint    YearBltBin
# 1860        1.0000   (-73.215, 44.47894)  (1950, 2015]
# 9583        0.3000  (-73.2063, 44.47431)     (0, 1905]
# 3519        0.2782   (-73.213, 44.47275)  (1950, 2015]
#
# [3 rows x 38 columns]

# %% [markdown]
# Get Dummies
# -------
# This is used to change categorical information to multiple true false columns

# %%
foundation = pd.get_dummies(df['ZoningCode'], prefix = 'ZoningCode')
foundation.head(3)
# Out:
#       ZoningCode_BST  ZoningCode_D  ZoningCode_DT  ZoningCode_DW  \
# 1860             0.0           1.0            0.0            0.0
# 9583             0.0           0.0            0.0            0.0
# 3519             0.0           0.0            0.0            0.0
#
#       ZoningCode_DWPT  ZoningCode_EAE  ZoningCode_ELM  ZoningCode_I  \
# 1860              0.0             0.0             0.0           0.0
# 9583              0.0             0.0             0.0           1.0
# 3519              0.0             0.0             0.0           0.0
#
#       ZoningCode_NAC  ZoningCode_NACR      ...        ZoningCode_RCOA  \
# 1860             0.0              0.0      ...                    0.0
# 9583             0.0              0.0      ...                    0.0
# 3519             0.0              0.0      ...                    0.0
#
#       ZoningCode_RCOC  ZoningCode_RCOG  ZoningCode_RH  ZoningCode_RL  \
# 1860              0.0              0.0            0.0            0.0
# 9583              0.0              0.0            0.0            0.0
# 3519              0.0              0.0            0.0            0.0
#
#       ZoningCode_RL-W  ZoningCode_RLW  ZoningCode_RM  ZoningCode_RMW  \
# 1860              0.0             0.0            0.0             0.0
# 9583              0.0             0.0            0.0             0.0
# 3519              0.0             0.0            1.0             0.0
#
#       ZoningCode_UR
# 1860            0.0
# 9583            0.0
# 3519            0.0
#
# [3 rows x 21 columns]

# %% [markdown]
# Merging and Joining
# -------

# %%
# Convert Series datatype to numeric, getting rid of any non-numeric values
#df['ZoningCode'] = df['ZoningCode'].astype(str).to_numeric()
#df['ZoningCode']

# %%
#Merge two different datasets
# dfmerged = pd.merge(set1,set2,on=proper)

# %%
#concatdf = pd.concat([One, TotalGrossArea, FinishedArea, CurrentValue,], axis=1)

# %% [markdown]
# Lower-Case Column Names
# ------------

# %%
# Lower-case everything in a DataFrame column
df.CuO1LastName = df.CuO1LastName.str.lower()
df.head(2)
# Out:
#       AccountNumber       ParcelID     SpanNumber StreetNumber  \
# 1860           5333  044-4-033-000  114-035-15333           75
# 9583           7871  050-1-066-000  114-035-17871          225
#
#      AlternateNumber        StreetName Unit              CuO1LastName  \
# 1860             NaN         CHERRY ST  NaN  btc mall associates, llc
# 9583             NaN  SOUTH WILLARD ST  NaN    champlain college inc.
#
#      CuO1FirstName CuO2LastName      ...      GrantorName NumofRooms  \
# 1860           NaN          NaN      ...              NaN        605
# 9583           NaN          NaN      ...              NaN        400
#
#      NumofBedrooms BathsCombined  NumofUnits  ZoningCode  Foundation  \
# 1860           605         0 / 0         605           D           C
# 9583             0        11 / 0          20           I          BS
#
#       Depreciation   PropertyCenterPoint    YearBltBin
# 1860           1.0   (-73.215, 44.47894)  (1950, 2015]
# 9583           0.3  (-73.2063, 44.47431)     (0, 1905]
#
# [2 rows x 38 columns]

# %%
# Lower-case all DataFrame column names, this applies to the df unconditionally and may make troubleshooting hard if half way through
#df.columns = map(str.lower, df.columns)
df.head(1)
# Out:
#       AccountNumber       ParcelID     SpanNumber StreetNumber  \
# 1860           5333  044-4-033-000  114-035-15333           75
#
#      AlternateNumber StreetName Unit              CuO1LastName CuO1FirstName  \
# 1860             NaN  CHERRY ST  NaN  btc mall associates, llc           NaN
#
#      CuO2LastName      ...      GrantorName NumofRooms NumofBedrooms  \
# 1860          NaN      ...              NaN        605           605
#
#      BathsCombined  NumofUnits  ZoningCode  Foundation  Depreciation  \
# 1860         0 / 0         605           D           C           1.0
#
#       PropertyCenterPoint    YearBltBin
# 1860  (-73.215, 44.47894)  (1950, 2015]
#
# [1 rows x 38 columns]

# %% [markdown]
# Everything Below Is not yet ready for prime time
# =================

# %%
# Full list of .str functions: http://pandas.pydata.org/pandas-docs/stable/text.html
# Slice values in a DataFrame column (aka Series)
#df.column.str[0:2]

# %%
# Select from DataFrame using multiple keys of a hierarchical index
#df.xs(('index level 1 value','index level 2 value'), level=('level 1','level 2'))

# %%
# Change all NaNs to None (useful before loading to a db)
#df = df.where((pd.notnull(df)), None)
df.head(3)

# %%
# Pivot data (with flexibility about what what
# becomes a column and what stays a row)
# Syntax works on Pandas >= .14
#pd.pivot_table(
#  df,values='cell_value',
#  index=['col1', 'col2', 'col3'], #these stay as columns; will fail silently if any of these cols have null values
#  columns=['col4']) #data values in this column become their own column

# %%
# Concatenate two DataFrame columns into a new, single column
# (useful when dealing with composite keys, for example)
#df['newcol'] = df['col1'].map(str) + df['col2'].map(str)

# %%
# Doing calculations with DataFrame columns that have missing values
# In example below, swap in 0 for df['col1'] cells that contain null
df['new_col'] = np.where(pd.isnull(df['col1']),0,df['col1']) + df['col2']

# %%
# Split delimited values in a DataFrame column into two new columns
df['new_col1'], df['new_col2'] = zip(*df['original_col'].apply(lambda x: x.split(': ', 1)))

# %%
# Get rid of non-numeric values throughout a DataFrame:
for col in refunds.columns.values:
  refunds[col] = refunds[col].replace('[^0-9]+.-', '', regex=True)

# %%
# Collapse hierarchical column indexes
df.columns = df.columns.get_level_values(0)

# %%
# Convert Django queryset to DataFrame
qs = DjangoModelName.objects.all()
q = qs.values()
df = pd.DataFrame.from_records(q)

# %%
# Create a DataFrame from a Python dictionary
df = pd.DataFrame(list(a_dictionary.items()), columns = ['column1', 'column2'])

# %%
# Get a report of all duplicate records in a dataframe, based on specific columns
dupes = df[df.duplicated(['col1', 'col2', 'col3'], keep=False)]

# %%
# Set up formatting so larger numbers aren't displayed in scientific notation (h/t @thecapacity)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
wholedf['Date'] = pd.to_datetime(wholedf['Date'])
