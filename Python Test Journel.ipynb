# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
property = pd.read_csv('~/Desktop/pythonexplore/BurlingtonPropertyDetails.csv')
property.head(20)
# list(property)
# Out:
#          ParcelID  AccountNumber     SpanNumber StreetNumber  \
# 0   046-1-013-000           6416  114-035-16416          184
# 1   054-2-013-000           8950  114-035-18950           36
# 2   021-2-080-000            147  114-035-10147           21
# 3   049-3-059-000           7285  114-035-17285          214
# 4   046-2-001-000           6667  114-035-16667          106
# 5   044-1-201-000           4659  114-035-14659            9
# 6   045-1-035-000           5597  114-035-15597          344
# 7   050-1-098-000           7924  114-035-17924          404
# 8   044-1-019-000           4484  114-035-14484           31
# 9   044-3-237-000           5227  114-035-15227          148
# 10  049-3-202-000           7519  114-035-17519          175
# 11  044-4-050-000           5368  114-035-15368           67
# 12  049-1-039-000           6943  114-035-16943           56
# 13  054-1-003-000           8763  114-035-18763          526
# 14  049-4-067-000           7591  114-035-17591          370
# 15  044-2-104-000           4966  114-035-14966           45
# 16  039-4-049-000           3864  114-035-13864           38
# 17  046-3-070-000           6833  114-035-16833          440
# 18  044-4-103-000           5421  114-035-15421          226
# 19  044-1-287-000           4738  114-035-14738           61
#
#                CuO1LastName      CuO1FirstName   LandUse  CurrentAcres  \
# 0                     BRACE          WILLIAM H  2 Family          0.34
# 1   DOMINIC PROPERTIES, LLC                NaN  2 Family          0.13
# 2                      LYON    CASEY J D ET LA  2 Family          0.44
# 3                 CARPENTER        CATHERINE R  2 Family          0.08
# 4                    ALSTON           W KEMPER  2 Family          0.26
# 5                  KILMURRY        CHRISTOPHER  2 Family          0.11
# 6                    MARTIN           HANNAH H  2 Family          0.20
# 7                    RIEHLE             DUNLAP  2 Family          0.40
# 8                    BEEMAN             JOHN W  2 Family          0.11
# 9                     BURNS          CHARLES C  2 Family          0.13
# 10                  LATSHAW               RUTH  2 Family          0.31
# 11                DISTEFANO        SAMANTHA D.  2 Family          0.21
# 12               SCHOENBECK            LORILEE  2 Family          0.09
# 13                  BERNARD  CATHERINE BARBARA  2 Family          0.08
# 14                    ELABD              ELENI  2 Family          0.07
# 15                   MARTIN           EDWARD A  2 Family          0.09
# 16               PRUDENZANO         LORRAINE E  2 Family          0.09
# 17                   DOOLEY       HALINA GANGI  2 Family          0.09
# 18                    MARIA         JACQUELINE  2 Family          0.07
# 19                  BITTNER        JENNIFER L.  2 Family          0.09
#
#     TotalGrossArea  FinishedArea          ...           SalePrice  NumofRooms  \
# 0           3344.0       1609.50          ...                 NaN          10
# 1           3000.0       1440.00          ...            327000.0           8
# 2           3053.0       1430.25          ...            159500.0           8
# 3           4724.0       2416.00          ...                 NaN          10
# 4           5203.0       2516.00          ...                 NaN           9
# 5           2740.0       1725.00          ...            177000.0          10
# 6           4434.0       2160.00          ...            241200.0           9
# 7          12145.0       7598.25          ...                 NaN          12
# 8           4958.0       2206.00          ...            255000.0          11
# 9           4819.0       2956.00          ...            372500.0          13
# 10          5504.0       2937.00          ...            480000.0          11
# 11          4193.0       1946.50          ...            315000.0           8
# 12          3324.0       1914.00          ...            250000.0           8
# 13          3726.0       1691.25          ...                 NaN           9
# 14          3004.0       1678.00          ...                 NaN          11
# 15          4115.0       2063.25          ...                 NaN          10
# 16          2910.0       1364.00          ...                 NaN           6
# 17          2550.0       1385.50          ...            202000.0          12
# 18          6183.0       3360.05          ...                 NaN           9
# 19          3926.0       2388.00          ...            338000.0          12
#
#     NumofBedrooms  Bath1 Bath2 NumofUnits ZoningCode Foundation  Depreciation  \
# 0               4      2     0          2       NACR         BS          0.30
# 1               4      2     0          2         RL         BS          0.25
# 2               4      2     0          2         RL          C          0.30
# 3               3      2     0          2         RH         BS          0.40
# 4               4      2     0          2          I         BS          0.30
# 5               4      2     1          2        NMU         BS          0.40
# 6               3      3     0          2         RM         BS          0.38
# 7               6      3     2          2         RH         BS          0.49
# 8               4      2     1          2         RM         BS          0.30
# 9               8      4     0          2         RM         BS          0.30
# 10              5      3     1          2         RH         BS          0.25
# 11              3      2     0          2         RH         BS          0.21
# 12              4      2     0          2         RH         BS          0.19
# 13              5      2     0          2         RL         BS          0.30
# 14              4      3     0          2         RM         BS          0.40
# 15              5      2     0          2         RH         BS          0.27
# 16              4      2     0          2         RM         BS          0.30
# 17              2      2     0          2         RL         BS          0.30
# 18              4      2     1          2         RH         BS          0.23
# 19              6      2     0          2         RM         BS          0.23
#
#      PropertyCenterPoint
# 0    (-73.191, 44.48612)
# 1   (-73.2074, 44.46423)
# 2   (-73.2681, 44.52544)
# 3   (-73.2106, 44.47399)
# 4    (-73.196, 44.48118)
# 5   (-73.2154, 44.48502)
# 6    (-73.2077, 44.4852)
# 7   (-73.2034, 44.47788)
# 8   (-73.2205, 44.48541)
# 9    (-73.2094, 44.4847)
# 10  (-73.2094, 44.47521)
# 11  (-73.2142, 44.48228)
# 12  (-73.2176, 44.47369)
# 13  (-73.2081, 44.46594)
# 14  (-73.2115, 44.46968)
# 15  (-73.2154, 44.48161)
# 16  (-73.2135, 44.48726)
# 17  (-73.1873, 44.48694)
# 18  (-73.2097, 44.48072)
# 19  (-73.2209, 44.48366)
#
# [20 rows x 30 columns]

# %%
baths = property[['Bath1','Bath2','NumofBedrooms']]
plt.scatter(baths['Bath2'],baths['Bath1'])

# %% [markdown]
# Take the propert data set, return columns CurrentAcres	TotalGrossArea	FinishedArea only.  Then refine the dataset to not have any values over 150,000 to removed the larger multifamily homes.  Plot the values as a matplotlib scatter plot.

# %%
size = property.ix[:,'CurrentAcres':'FinishedArea']
sizerefined = size[(size['FinishedArea'] < 150000) & (size['TotalGrossArea'] < 150000)]
plt.scatter(sizerefined['TotalGrossArea'],sizerefined['FinishedArea'])

# %%
onefamily = property[property['LandUse'] == "1 Family"]
sizeonefamily = onefamily.ix[:,'CurrentAcres':'FinishedArea']
sizeonefamilyrefined = sizeonefamily[(sizeonefamily['FinishedArea'] < 150000) & (sizeonefamily['TotalGrossArea'] < 150000)]
plt.scatter(sizeonefamilyrefined['TotalGrossArea'],sizeonefamilyrefined['FinishedArea'])

# %%
twofamily = property[property['LandUse'] == "2 Family"]
sizetwofamily = twofamily.ix[:,'CurrentAcres':'FinishedArea']
sizetwofamilyrefined = sizetwofamily[(sizetwofamily['FinishedArea'] < 150000) & (sizetwofamily['TotalGrossArea'] < 150000)]
plt.scatter(sizetwofamilyrefined['TotalGrossArea'],sizetwofamilyrefined['FinishedArea'])

# %%
# Out:
#   File "<ipython-input-52-1ec77c78464e>", line 1
#     [X,Y] = meshgrid(-2:.2:2);
#                        ^
# SyntaxError: invalid syntax
